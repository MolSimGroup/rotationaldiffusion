# %% [markdown]
# # Tutorial
#
# This tutorial provides a step-by-step guide to analyzing rotational diffusion of molecules from molecular dynamics simulations using the `rotationaldiffusion` package.
#
# ## Introduction
#
# Rotational diffusion describes how molecules reorient in solution. For rigid bodies, this diffusion process is described by a rotational diffusion tensor, which can be characterized using its principal components (eigenvalues) $D_x$, $D_y$, and $D_z$ along the principal axes of the molecule.
#
# In this tutorial, we'll:
# 1. Extract the orientations of a molecule over time
# 2. Compute the covariance matrix / rotational correlation functions
# 3. Fit a rotational diffusion model
# 4. Analyze and visualize the results

# %% [markdown]
# ## Setup
#
# First, let's import the necessary packages:

# %%
import numpy as np
import matplotlib.pyplot as plt
import MDAnalysis as mda
from MDAnalysisTests.datafiles import PSF, DCD
import rotationaldiffusion as rd

# Set up matplotlib for better visualization
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['font.size'] = 12
# Out:
# /home/sholtbruegge/mambaforge/envs/testing/lib/python3.11/site-packages/Bio/Application/__init__.py:40: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %% [markdown]
# ## Calculating Orientations
#
# The first step in analyzing rotational diffusion is to calculate the orientations of the molecule at each time point. The `rotationaldiffusion` package provides the `Orientations` analysis class for this purpose. Here, we are exploring this class using a short trajectory from `MDAnalysisTests`.

# %%
# Load trajectory
u = mda.Universe(PSF, DCD)

# Select the atoms for analysis.
selection = "name CA or name C or name N" # Protein backbone

# Initialize the orientation analysis.
orient_analysis = rd.orientations.Orientations(u, select=selection, unwrap=False)

# Run the analysis.
orient_analysis.run()

# Get the resulting orientations (rotation matrices).
orientations = orient_analysis.results.orientations
print(f"Calculated {len(orientations)} orientation matrices of shape {orientations[0].shape}")
# Out:
# Calculated 98 orientation matrices of shape (3, 3)
# /home/sholtbruegge/mambaforge/envs/testing/lib/python3.11/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"

# %% [markdown]
# **Note:** By default, molecules will be unwrapped and centered. This behaviour can be overwritten by setting `unwrap=False` and `center=False`, to speed up computations in case the provided trajectories are already unwrapped and centered. Also, the `Orientations` class supports parallelization using `multiprocessing` or `dask`, which can be enabled by passing the `backend` and `n_workers` flags to the `.run()` method.

# %% [markdown]
# ## Computing the covariance matrix / rotational correlation functions.
#
# Next, we'll compute a covariance matrix containing six rotational correlation functions, which describe how the orientation decorrelates over time. We are switching to orientations pre-computed from ten MD simulations of Ubiquitin, lasting $1 \mu s$ each.

# %%
# Load data.
orientations = np.load('data/orientations.npy')

# Compute the covariance matrix Q by correlating the orientations.
correlations = rd.correlate(orientations)
print(f"Computed correlation matrix Q with shape {correlations.shape}")

# Average over all 10 simulations.
correlations_av = np.mean(correlations, axis=0)

# Get corresponding lag times.
timestep = 0.1  # ns
lag_times = np.arange(1, len(correlations_av)) * timestep
print(f"Lag times range from {lag_times[0]} to {lag_times[-1]} ns")
# Out:
# Computed correlation matrix Q with shape (10, 1000, 3, 3)
# Lag times range from 0.1 to 99.9 ns

# %% [markdown]
# ## Visualizing Correlations
#
# Let's visualize the rotational correlation functions to understand how the orientations decorrelate over time.

# %%
# Create a plot for visualizing Q matrix components
fig, ax = plt.subplots()

# Set axis labels.
ax.set_xlabel('$\\tau$ / ns')
ax.set_ylabel(r'$\bf{\~{Q}}$'+"$_{{{i}{j}}}$")

# Some helper variables.
_ndx_fin = 500
_corr = np.moveaxis(Q_data_av, 0, -1)

# Plot the diagonal correlation functions.
for i in range(3):
    ax.plot(lag_times[:_ndx_fin], _corr[i, i, :_ndx_fin], label=r'$\bf{\tilde{Q}}$'+f"$_{{{i+1}{i+1}}}$")

# Plot the off-diagonal correlation functions.
for i in range(3):
    j, k = max(i, 1) - 1, min(i, 1) + 1
    ax.plot(lag_times[:_ndx_fin], _corr[j, k, :_ndx_fin], label=r'$\bf{\tilde{Q}}$'+f"$_{{{j+1}{k+1}}}$")
    
ax.legend(ncol=2)

# %% [markdown]
# The results look exactly as expected. The diagonal correlation functions begin at zero, rise, and converge to values close to 0.25. In contrast, the off-diagonal correlation functions remain close to zero. These features should be checked when analyzing rotational diffusion from MD.

# %% [markdown]
# ## Time-Dependent Diffusion Coefficients
#
# We can compute the time-dependent diffusion coefficients to see how the diffusion behavior changes with correlation time.

# %%
# Calculate time-dependent diffusion coefficients and principal axes
D_time_dep, PAF_time_dep = rd.instantaneous_tensors(lag_times, correlations)

# Plot time-dependent diffusion coefficients
fig, ax = 
plt.figure(figsize=(10, 6))
plt.plot(lag_times, D_inst[:, 0], 'o-', label='D₁')
plt.plot(lag_times, D_inst[:, 1], 'o-', label='D₂')
plt.plot(lag_times, D_inst[:, 2], 'o-', label='D₃')
plt.xlabel('Lag time (ps)')
plt.ylabel('Diffusion coefficient (rad²/ps)')
plt.legend()
plt.title('Time-dependent diffusion coefficients')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Fitting a Diffusion Model
#
# Now we'll fit a rotational diffusion model to the correlation data. We can choose between three models:
# - `anisotropic`: Full anisotropic diffusion with three independent coefficients (D₁, D₂, D₃)
# - `semi-isotropic`: Axially symmetric diffusion (D∥, D⊥)
# - `isotropic`: Isotropic diffusion with a single coefficient (D)

# %%
# Fit an anisotropic diffusion model
# Note: We'll use a subset of lag times where the instantaneous D values are relatively stable
fit_window = slice(0, 20)  # Adjust based on your data

fit_aniso = rd.least_squares_fit(lag_times[fit_window], Q_data[fit_window], model='anisotropic')
fit_semi = rd.least_squares_fit(lag_times[fit_window], Q_data[fit_window], model='semi-isotropic')
fit_iso = rd.least_squares_fit(lag_times[fit_window], Q_data[fit_window], model='isotropic')

print(f"Anisotropic model - D: {fit_aniso.D} rad²/ps, shape: {fit_aniso.shape}")
print(f"Semi-isotropic model - D: {fit_semi.D} rad²/ps, shape: {fit_semi.shape}")
print(f"Isotropic model - D: {fit_iso.D} rad²/ps, shape: {fit_iso.shape}")
# Out:
# Anisotropic model - D: [5.84912444e-07 2.49448822e-06 4.76530974e-06] rad²/ps, shape: triaxial
# Semi-isotropic model - D: [5.28160845e-06 5.28160845e-06 5.47135811e-07] rad²/ps, shape: oblate
# Isotropic model - D: [2.67573563e-06 2.67573563e-06 2.67573563e-06] rad²/ps, shape: spherical
# /home/sholtbruegge/mambaforge/envs/testing/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:231: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(self.x - self.x_prev, self.g - self.g_prev)
# ...

# %% [markdown]
# ## Evaluating Model Fits
#
# Let's compare the fitted models to the experimental correlation data:

# %%
# Generate model predictions
Q_aniso = rd.construct_Q_model(lag_times, fit_aniso.D, fit_aniso.rotation_axes)
Q_semi = rd.construct_Q_model(lag_times, fit_semi.D)
Q_iso = rd.construct_Q_model(lag_times, fit_iso.D)

# Plot comparison of experimental data with model fits
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Plot Q[0,0] component
axs[0].plot(lag_times, Q_data[:, 0, 0], 'o', label='Data')
axs[0].plot(lag_times, Q_aniso[:, 0, 0], '-', label='Anisotropic')
axs[0].plot(lag_times, Q_semi[:, 0, 0], '--', label='Semi-isotropic')
axs[0].plot(lag_times, Q_iso[:, 0, 0], ':', label='Isotropic')
axs[0].set_xlabel('Lag time (ps)')
axs[0].set_ylabel('Q[0,0]')
axs[0].legend()
axs[0].set_title('Q[0,0] Component')

# Plot Q[1,1] component
axs[1].plot(lag_times, Q_data[:, 1, 1], 'o', label='Data')
axs[1].plot(lag_times, Q_aniso[:, 1, 1], '-', label='Anisotropic')
axs[1].plot(lag_times, Q_semi[:, 1, 1], '--', label='Semi-isotropic')
axs[1].plot(lag_times, Q_iso[:, 1, 1], ':', label='Isotropic')
axs[1].set_xlabel('Lag time (ps)')
axs[1].set_ylabel('Q[1,1]')
axs[1].legend()
axs[1].set_title('Q[1,1] Component')

# Plot Q[2,2] component
axs[2].plot(lag_times, Q_data[:, 2, 2], 'o', label='Data')
axs[2].plot(lag_times, Q_aniso[:, 2, 2], '-', label='Anisotropic')
axs[2].plot(lag_times, Q_semi[:, 2, 2], '--', label='Semi-isotropic')
axs[2].plot(lag_times, Q_iso[:, 2, 2], ':', label='Isotropic')
axs[2].set_xlabel('Lag time (ps)')
axs[2].set_ylabel('Q[2,2]')
axs[2].legend()
axs[2].set_title('Q[2,2] Component')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing the Principal Axes
#
# For anisotropic diffusion, it's useful to visualize the principal axes of the diffusion tensor:

# %%
# Create a 3D plot to visualize the principal axes
from mpl_toolkits.mplot3d import Axes3D

if fit_aniso.rotation_axes is not None:
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Origin
    ax.scatter([0], [0], [0], color='k', s=100)
    
    # Scale factors for axis visualization (proportional to sqrt(D))
    scale_factors = np.sqrt(fit_aniso.D) / np.sqrt(np.max(fit_aniso.D)) * 3
    
    # Colors for each axis
    colors = ['r', 'g', 'b']
    
    # Plot each principal axis
    for i in range(3):
        axis = fit_aniso.rotation_axes[i]
        ax.quiver(0, 0, 0, 
                 axis[0] * scale_factors[i], 
                 axis[1] * scale_factors[i], 
                 axis[2] * scale_factors[i], 
                 color=colors[i], linewidth=2, 
                 arrow_length_ratio=0.1)
        
        # Add a text label for each axis
        ax.text(axis[0] * scale_factors[i] * 1.1, 
                axis[1] * scale_factors[i] * 1.1, 
                axis[2] * scale_factors[i] * 1.1, 
                f'D{i+1}={fit_aniso.D[i]:.2f}', color=colors[i])
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_xlim([-3, 3])
    ax.set_ylim([-3, 3])
    ax.set_zlim([-3, 3])
    ax.set_title('Principal Axes of the Diffusion Tensor')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Computing Anisotropy
#
# The anisotropy of rotational diffusion can be quantified in several ways:

# %%
# Calculate different measures of anisotropy
D = fit_aniso.D
D_par = D[2]  # Assuming D is sorted, D[2] is the largest component
D_perp = (D[0] + D[1]) / 2  # Average of the two smaller components

# Parallel-to-perpendicular ratio
par_perp_ratio = D_par / D_perp

# Another common anisotropy measure
anisotropy = 2 * D[2] / (D[0] + D[1])

# Relative anisotropy (difference between max and min, divided by average)
rel_anisotropy = (D[2] - D[0]) / np.mean(D)

print(f"Parallel-to-perpendicular ratio: {par_perp_ratio:.2f}")
print(f"Anisotropy (2*D₃/(D₁+D₂)): {anisotropy:.2f}")
print(f"Relative anisotropy ((D₃-D₁)/⟨D⟩): {rel_anisotropy:.2f}")
# Out:
# Parallel-to-perpendicular ratio: 3.09
# Anisotropy (2*D₃/(D₁+D₂)): 3.09
# Relative anisotropy ((D₃-D₁)/⟨D⟩): 1.60

# %% [markdown]
# ## Summary
#
# In this tutorial, we've demonstrated how to use the `rotationaldiffusion` package to:
#
# 1. Extract orientations from a molecular dynamics trajectory
# 2. Compute quaternion correlation functions
# 3. Analyze time-dependent diffusion behavior
# 4. Fit various rotational diffusion models
# 5. Visualize and interpret the results
#
# The rotational diffusion coefficients provide valuable insights into the rotational dynamics of molecules in solution, which can be correlated with molecular properties such as size, shape, and flexibility.
